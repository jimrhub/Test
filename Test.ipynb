# %% [markdown]
# <a href="https://colab.research.google.com/github/GitMecHub/Test/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#testing

# %%
print("hello, world")
# Out:
# hello, world

# %% [markdown]
# Internet picture
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Test1

# %% [markdown]
# Local Picture
#
# ![Mechub_yt_banner.png](data:image/png;base64,...)

# %% [markdown]
# what if i change this code, do i need to create another copy?
